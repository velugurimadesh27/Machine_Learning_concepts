# %% [markdown]
# #importing pandas

# %%
import pandas as pd

# %% [markdown]
# #2.opening a local csv file

# %%
df = pd.read_csv('/content/matches.csv')
df.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %% [markdown]
# #3.opening a csv file from url

# %%
import requests
from io import StringIO
url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
headers={"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101} Firefox/66.0"}
req = requests.get(url,headers=headers)
data = StringIO(req.text)
pd.read_csv(data)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #4.sep parameter and index_col

# %%
pd.read_csv('/content/products_no_headers.tsv',sep = '\t',names=['product_id','product','category','price','stock'],index_col='product_id')
# Out:
#                product     category  price  stock
# product_id
# 101             Laptop  Electronics  65000     12
# 102              Mouse  Accessories   1200     50
# 103           Keyboard  Accessories   2500     35
# 104            Monitor  Electronics  18000     18
# 105         Headphones        Audio   3500     40
# 106             Webcam  Electronics   4200     25
# 107             Tablet  Electronics  28000     10
# 108            Speaker        Audio   5000     30

# %% [markdown]
# #5.Header parameter

# %%
pd.read_csv("/content/students_with_header.tsv",sep='\t',header=0)
# Out:
#    Student_ID    Name  Age  Marks Department
# 0         101    Arun   20     82       AIML
# 1         102    Bala   21     75        CSE
# 2         103  Charan   20     91       AIML
# 3         104   Divya   19     68        ECE
# 4         105    Esha   22     88        CSE
# 5         106  Farhan   21     79       AIML
# 6         107    Gita   20     95         IT
# 7         108    Hari   23     72        CSE

# %% [markdown]
# #6.Use_columns

# %%
pd.read_csv('/content/matches.csv',usecols=['team1','team2','winner']).head()
# Out:
#                          team1                        team2  \
# 0          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1               Mumbai Indians       Rising Pune Supergiant
# 2                Gujarat Lions        Kolkata Knight Riders
# 3       Rising Pune Supergiant              Kings XI Punjab
# 4  Royal Challengers Bangalore             Delhi Daredevils
#
#                         winner
# 0          Sunrisers Hyderabad
# 1       Rising Pune Supergiant
# 2        Kolkata Knight Riders
# 3              Kings XI Punjab
# 4  Royal Challengers Bangalore

# %% [markdown]
# Squeeze paramter

# %%
from numpy import squeeze
df = pd.read_csv('/content/matches.csv',usecols=['city'])
result = df.squeeze()
type(df)
type(result)
df
# Out:
#           city
# 0    Hyderabad
# 1         Pune
# 2       Rajkot
# 3       Indore
# 4    Bangalore
# ..         ...
# 631     Raipur
# 632  Bangalore
# 633      Delhi
# 634      Delhi
# 635  Bangalore
#
# [636 rows x 1 columns]

# %% [markdown]
# #skiprows and nrows

# %%
pd.read_csv('/content/matches.csv',skiprows=[1,2,3],nrows=100)
# Out:
#      id  season       city        date                        team1  \
# 0     4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 1     5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 2     6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 3     7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 4     8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# ..  ...     ...        ...         ...                          ...
# 95   99    2008     Mumbai  2008-05-16        Kolkata Knight Riders
# 96  100    2008      Delhi  2008-05-17             Delhi Daredevils
# 97  101    2008     Jaipur  2008-05-17             Rajasthan Royals
# 98  102    2008  Hyderabad  2008-05-18               Mumbai Indians
# 99  103    2008    Kolkata  2008-05-18        Kolkata Knight Riders
#
#                           team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# #Encoding parameter

# %%
pd.read_csv('/content/zomato_encoding_practice.csv',encoding='utf-8')
# Out:
#         Restaurant        City        Cuisine  Rating  Price_for_two
# 0    Biryani House   Hyderabad        Biryani     4.5            500
# 1  Café Coffee Day   Bengaluru           Café     4.1            700
# 2       Chai & Co.     Chennai  Indian Snacks     4.3            300
# 3           東京ラーメン       Tokyo       Japanese     4.6            900
# 4             北京饭店     Beijing        Chinese     4.2            800
# 5            서울 키친       Seoul         Korean     4.4            850
# 6     Bombay Spice      Mumbai   North Indian     4.0            600
# 7   Andhra Ruchulu  Vijayawada   South Indian     4.7            450

# %% [markdown]
# #dtypes parameter

# %%
pd.read_csv('/content/matches.csv',dtype={'umpire3':'Int64'}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %% [markdown]
# #Convertors

# %%
def rename(name):
    if name=="Royal Challengers Bangalore":
        return "RCB"
    else:
        return name

# %%
rename("Royal Challengers Bangalore")
# Out:
# 'RCB'

# %%
pd.read_csv('/content/matches.csv',converters={'team1':rename})
# Out:
#       id  season       city        date                   team1  \
# 0      1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06          Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3      4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08                     RCB
# ..   ...     ...        ...         ...                     ...
# 631  632    2016     Raipur  2016-05-22        Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24           Gujarat Lions
# 633  634    2016      Delhi  2016-05-25     Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27           Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29     Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %% [markdown]
# #na_values parameter

# %%
pd.read_csv("/content/aug_train.csv",na_values=['Male'],na_filter=True).head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920    NaN
# 1        29725   city_40                   0.776    NaN
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# #Loading a huge dataset in chunks

# %%
dfs = pd.read_csv("/content/aug_train.csv",chunksize=5000)

# %%
for chunk in dfs:
    print(chunk.shape)

# %%
print(chunks.shape)
# Out:
# (4158, 14)
