# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/StudentsPerformance.csv')

# %% [markdown]
# #understanding the data

# %%
df.sample(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 785  female        group B            some high school      standard
# 590    male        group C                some college  free/reduced
# 908  female        group C           bachelor's degree  free/reduced
# 23   female        group C            some high school      standard
# 6    female        group B                some college      standard
#
#     test preparation course  math score  reading score  writing score
# 785               completed          32             51             44
# 590                    none          58             57             54
# 908                    none          67             75             72
# 23                     none          69             73             73
# 6                 completed          88             95             92

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.corr(numeric_only=True)
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %% [markdown]
# #EDA-univariate analysis

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
sns.countplot(x=df['gender'])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
df['gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %%
df['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
df['race/ethnicity'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x=df['race/ethnicity'])
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %%
df['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
sns.countplot(y=df['parental level of education'])
# Out:
# <Axes: xlabel='count', ylabel='parental level of education'>

# %%
df['parental level of education'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(x=df['math score'])
plt.xlabel('score ranges')
plt.ylabel('no of students')
# Out:
# Text(0, 0.5, 'no of students')

# %%
df['math score'].min()
# Out:
# 0

# %%
sns.histplot(x=df['reading score'])
# Out:
# <Axes: xlabel='reading score', ylabel='Count'>

# %%
sns.boxplot(x=df['writing score'])
# Out:
# <Axes: xlabel='writing score'>

# %% [markdown]
# #Multivariate analysis

# %%
df.sample(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 34     male        group E                some college      standard
# 481  female        group D          associate's degree  free/reduced
# 904  female        group D            some high school  free/reduced
# 914  female        group B          associate's degree  free/reduced
# 339  female        group D            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 34                     none          97             87             82
# 481                    none          52             59             56
# 904                    none          67             84             84
# 914                    none          46             61             55
# 339               completed          35             55             60

# %%
sns.scatterplot(x=df['math score'],y=df['reading score'],hue=df['gender'],style=df['test preparation course'],size=df['race/ethnicity'])
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %%
sns.barplot(y=df['reading score'],x=df['test preparation course'],hue=df['gender'])
# Out:
# <Axes: xlabel='test preparation course', ylabel='reading score'>

# %%
sns.boxplot(y=df['reading score'],x=df['test preparation course'],hue=df['gender'])
# Out:
# <Axes: xlabel='test preparation course', ylabel='reading score'>

# %%
sns.displot(
    data=df,
    x='writing score',
    hue='race/ethnicity',
    kind='kde'

)
